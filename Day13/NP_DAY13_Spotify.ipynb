# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('d4b8b8fcc551418c824db99cd456530f','679f30419efe49999b4871e1e779f1e8'))

# %%
#https://open.spotify.com/playlist/4hOKQuZbraPDIfaGbM3lKI
tracks = spotify.playlist_tracks('4hOKQuZbraPDIfaGbM3lKI')

# %%
tracks.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
tracks['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
track= tracks['items'][99]

# %%
track['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
track['track']['name']
track['track']['id']
track['track']['duration_ms']/(1000)

#track['track']['available_markets']
track['track']['popularity']
track['track']['episode']
track['track']['artists']
track['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4u5smJBskI6Adzv08PuiUP'},
#    'href': 'https://api.spotify.com/v1/artists/4u5smJBskI6Adzv08PuiUP',
#    'id': '4u5smJBskI6Adzv08PuiUP',
#    'name': 'Kiiara',
#    'type': 'artist',
#    'uri': 'spotify:artist:4u5smJBskI6Adzv08PuiUP'}],
#  'available_markets': ['AD',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BG',
#   'BI',
#   'BJ',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'ES',
#   'ET',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
# ...

# %%
names = []
ids = []
duration = []
album_type = []
for track in tracks['items']:
    names.append(track['track']['name'])
    ids.append(track['track']['id'])
    duration.append(track['track']['duration_ms']/1000)
    album_type.append(track['track']['album']['album_type'])

# %%
import pandas as pd
df = pd.DataFrame({'name':names , 'id':ids , 'duration': duration , 'album_type' : album_type})

# %%
df
# Out:
#                           name                      id  duration album_type
# 0            Despacito - Remix  5CtI0qwDJkDQGwXD1H1cLb   228.826     single
# 1                  I'm the One  72Q0FQQo32KJloivv5xge2   288.876     single
# 2                 Shape of You  7qiZfU4dY1lWllzX7mPBI3   233.712      album
# 3                      HUMBLE.  7KXjTSCq5nL1LoYtL7XAwS   177.000      album
# 4                     Mask Off  3rOSwuTsUlJp0Pu0MkN8r8   204.600      album
# ..                         ...                     ...       ...        ...
# 95                   24K Magic  6b8Be6ljOzmkOmFslEb23P   225.983      album
# 96                     Tu Foto  0Szp49tpFasIjX04Mcsydp   193.117     single
# 97                     T-Shirt  7KOlJ92bu51cltsD9KU5I7   242.407      album
# 98                Sola (Remix)  5q2JbCNi4FcnglgPfxcV65   307.910     single
# 99  Whippin (feat. Felix Snow)  3QWjljChcOMkRDYSzF33Qr   160.596     single
#
# [100 rows x 4 columns]
