# %%
emp = {"name":"nidhi","gender":"Female","email_id":"nidhig631@gmail.com"}

# %%
emp
# Out:
# {'name': 'nidhi', 'gender': 'Female', 'email_id': 'nidhig631@gmail.com'}

# %%
emp = {"name":["A1","A2","A3"]
       ,"Gender":["M","F","M"],
       "email":["n@gmail.com","p@gmail.com","m@gmail.com"]}

# %%
emp
# Out:
# {'name': ['A1', 'A2', 'A3'],
#  'Gender': ['M', 'F', 'M'],
#  'email': ['n@gmail.com', 'p@gmail.com', 'm@gmail.com']}

# %%
import pandas as pd

# %%
df_emp =pd.DataFrame(emp)

# %%
df_emp
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
type(df_emp)
# Out:
# pandas.core.frame.DataFrame

# %%
df_emp["name"] #access  specific column
# Out:
# 0    A1
# 1    A2
# 2    A3
# Name: name, dtype: object

# %%
df_emp.name
# Out:
# 0    A1
# 1    A2
# 2    A3
# Name: name, dtype: object

# %%
df_emp.info() # represent whole data type info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   Gender  3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %%
df_emp.describe() # all statistics
# Out:
#        name Gender        email
# count     3      3            3
# unique    3      2            3
# top      A1      M  n@gmail.com
# freq      1      2            1

# %%
type(df_emp.name)  # type of single column is series
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv("orders.txt",delimiter=',')

# %%
df.describe()
# Out:
#               sales       profit
# count   5009.000000  5009.000000
# mean     221.120564    21.032394
# std      470.243724   168.715780
# min        0.444000 -2929.484500
# 25%       16.768000     1.068000
# 50%       56.520000     7.482400
# 75%      225.296000    26.388000
# max    10499.970000  5039.985600

# %%
df.head()
# Out:
#          order_id  order_date     customer_name           city
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City  \
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
# 3  CA-2018-100328  2018-01-28   Jasper Cacioppo  New York City
# 4  CA-2018-100363  2018-04-08       Jim Mitchum       Glendale
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3  Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4  Office Supplies  OFF-FA-10000611    2.368    0.8288

# %%
df.head(20)
# Out:
#           order_id  order_date      customer_name            city
# 0   CA-2018-100006  2018-09-07        Dennis Kane   New York City  \
# 1   CA-2018-100090  2018-07-08         Ed Braxton   San Francisco
# 2   CA-2018-100293  2018-03-14   Neil Französisch    Jacksonville
# 3   CA-2018-100328  2018-01-28    Jasper Cacioppo   New York City
# 4   CA-2018-100363  2018-04-08        Jim Mitchum        Glendale
# 5   CA-2018-100391  2018-05-25      Barry Weirich   New York City
# 6   CA-2018-100678  2018-04-18       Kunst Miller         Houston
# 7   CA-2018-100706  2018-12-16    Laurel Elliston     Springfield
# 8   CA-2018-100762  2018-11-24         Nat Gilpin         Jackson
# 9   CA-2018-100860  2018-03-26      Cindy Stewart          Pomona
# 10  CA-2018-100867  2018-10-19  Eugene Hildebrand        Lakewood
# 11  CA-2018-100881  2018-03-28      Daniel Raglin     Albuquerque
# 12  CA-2018-100895  2018-06-02   Stewart Visinsky         Roswell
# ...

# %%
df.tail(10)
# Out:
#             order_id  order_date      customer_name           city
# 4999  US-2021-167570  2021-12-08        Emily Grady   Philadelphia  \
# 5000  US-2021-167920  2021-12-09           John Lee       Richmond
# 5001  US-2021-168116  2021-11-04     Grant Thornton     Burlington
# 5002  US-2021-168613  2021-10-08        Gary McGarr  New York City
# 5003  US-2021-168690  2021-01-07      Thais Sissman   Ormond Beach
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales   profit
# 4999        Furniture  FUR-CH-10003396  215.544 -58.5048
# 5000  Office Supplies  OFF-AP-10000159  214.900  62.3210
# 5001  Office Supplies  OFF-AP-10002457  167.440  14.6510
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5009 entries, 0 to 5008
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       5009 non-null   object
#  1   order_date     5009 non-null   object
#  2   customer_name  5009 non-null   object
#  3   city           5009 non-null   object
#  4   category       5009 non-null   object
#  5   product_id     5009 non-null   object
#  6   sales          5009 non-null   float64
#  7   profit         5009 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 313.2+ KB

# %%
#multiple columns
col = ['order_id','order_date','category']
df[col]
# Out:
#             order_id  order_date         category
# 0     CA-2018-100006  2018-09-07       Technology
# 1     CA-2018-100090  2018-07-08        Furniture
# 2     CA-2018-100293  2018-03-14  Office Supplies
# 3     CA-2018-100328  2018-01-28  Office Supplies
# 4     CA-2018-100363  2018-04-08  Office Supplies
# ...              ...         ...              ...
# 5004  US-2021-168802  2021-11-03  Office Supplies
# 5005  US-2021-169320  2021-07-23  Office Supplies
# 5006  US-2021-169488  2021-09-07  Office Supplies
# 5007  US-2021-169502  2021-08-28  Office Supplies
# 5008  US-2021-169551  2021-07-07        Furniture
#
# [5009 rows x 3 columns]

# %%
df_emp
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
# iloc ==> (index/integer base) integer location always takes integer
# loc  ==> label base

# %%
df_emp.iloc[0,0]
# Out:
# 'A1'

# %%
df_emp.iloc[0,1]
# Out:
# 'M'

# %%
df_emp.iloc[1:3,0:2]
# Out:
#   name Gender
# 1   A2      F
# 2   A3      M

# %%
df_emp
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
#slicing
df_emp.iloc[1:3,0:2]
# Out:
#   name Gender
# 1   A2      F
# 2   A3      M

# %%
df_emp.iloc[1,2]
# Out:
# 'p@gmail.com'

# %%
#select specific index (rows/columns)
df_emp.iloc[[0,2],[0,2]]
# Out:
#   name        email
# 0   A1  n@gmail.com
# 2   A3  m@gmail.com

# %%
#one row one column ==> series
#multiple row and column ==> dataframe

# %%
df_emp
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
#loc(label base)
#here it is label base not index so 2 label data getting
df_emp.loc[0:2,['name','email']]
# Out:
#   name        email
# 0   A1  n@gmail.com
# 1   A2  p@gmail.com
# 2   A3  m@gmail.com

# %%
df_emp.loc[0:2,'name':'email']
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
df_emp.set_index('email')
# Out:
#             name Gender
# email
# n@gmail.com   A1      M
# p@gmail.com   A2      F
# m@gmail.com   A3      M

# %%
df_emp
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
#dataframe is mutable in python
#using inplace = True we can

# %%
df_emp.loc[1:2]
# Out:
#   name Gender        email
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
df_emp.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df_emp.reset_index(inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6219, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6213         if lab is not None:
#    6214             # if we have the codes, extract the values with a mask
#    6215             level_values = algorithms.take(
#    6216                 level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6217             )
# -> 6219         new_obj.insert(
#    6220             0,
#    6221             name,
#    6222             level_values,
#    6223             allow_duplicates=allow_duplicates,
#    6224         )
#    6226 new_obj.index = new_index
#    6227 if not inplace:
#
# ...

# %%
df_emp.iloc[1,2]
# Out:
# 'A2'

# %%
df_emp
# Out:
#    level_0  index name Gender        email
# 0        0      0   A1      M  n@gmail.com
# 1        1      1   A2      F  p@gmail.com
# 2        2      2   A3      M  m@gmail.com

# %%
df_emp.iloc[0:2,0:2]
# Out:
#    level_0  index
# 0        0      0
# 1        1      1

# %%
df
# Out:
#             order_id  order_date      customer_name           city
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City  \
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df.iloc[2:6,1:3] #df.iloc[row,colun]
# Out:
#    order_date     customer_name
# 2  2018-03-14  Neil Französisch
# 3  2018-01-28   Jasper Cacioppo
# 4  2018-04-08       Jim Mitchum
# 5  2018-05-25     Barry Weirich

# %%
df.loc[[2,5],'order_id']
# Out:
# 2    CA-2018-100293
# 5    CA-2018-100391
# Name: order_id, dtype: object

# %%
df.sort_values('order_id')
# Out:
#             order_id  order_date      customer_name           city
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City  \
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df.sort_index(ascending=False)
# Out:
#             order_id  order_date      customer_name           city
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia  \
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# ...              ...         ...                ...            ...
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
#
#              category       product_id    sales    profit
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
# ...

# %%
df
# Out:
#             order_id  order_date      customer_name           city
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City  \
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df['category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    2773
# Furniture          1764
# Technology          472
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# New York City    450
# Los Angeles      384
# San Francisco    265
# Philadelphia     265
# Seattle          212
#                 ...
# Montebello         1
# Arvada             1
# Mason              1
# Shelton            1
# Elkhart            1
# Name: count, Length: 531, dtype: int64

# %%
df[['category','city']].value_counts()
# Out:
# category         city
# Office Supplies  New York City       257
#                  Los Angeles         210
# Furniture        New York City       157
# Office Supplies  Philadelphia        152
#                  San Francisco       149
#                                     ...
#                  North Charleston      1
#                  Norfolk               1
#                  Noblesville           1
#                  Niagara Falls         1
#                  Farmington            1
# Name: count, Length: 987, dtype: int64

# %%
pd.options.display.max_rows=100

# %%
df_emp.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df_emp.reset_index(inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6219, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6213         if lab is not None:
#    6214             # if we have the codes, extract the values with a mask
#    6215             level_values = algorithms.take(
#    6216                 level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6217             )
# -> 6219         new_obj.insert(
#    6220             0,
#    6221             name,
#    6222             level_values,
#    6223             allow_duplicates=allow_duplicates,
#    6224         )
#    6226 new_obj.index = new_index
#    6227 if not inplace:
#
# ...

# %%
df_emp
# Out:
#    level_0  index name Gender        email
# 0        0      0   A1      M  n@gmail.com
# 1        1      1   A2      F  p@gmail.com
# 2        2      2   A3      M  m@gmail.com

# %%
df_emp['Gender']=='M'
# Out:
# 0     True
# 1    False
# 2     True
# Name: Gender, dtype: bool

# %%
df_emp
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 1   A2      F  p@gmail.com
# 2   A3      M  m@gmail.com

# %%
fc = (df_emp["Gender"] == 'M')

# %%
fc
# Out:
# 0     True
# 1    False
# 2     True
# Name: Gender, dtype: bool

# %%
df_emp[fc]
# Out:
#   name Gender        email
# 0   A1      M  n@gmail.com
# 2   A3      M  m@gmail.com

# %%
fci = ~(df_emp['Gender']=='M')

# %%
fci
# Out:
# 0    False
# 1     True
# 2    False
# Name: Gender, dtype: bool

# %%
df_emp[fci]
# Out:
#   name Gender        email
# 1   A2      F  p@gmail.com

# %%
fcn = (df_emp["Gender"] != 'M')

# %%
fcn
# Out:
# 0    False
# 1     True
# 2    False
# Name: Gender, dtype: bool

# %%
df_emp[fcn]
# Out:
#   name Gender        email
# 1   A2      F  p@gmail.com

# %%
df
# Out:
#             order_id  order_date      customer_name           city
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City  \
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
fcg = (df['category']=='Furniture')

# %%
fcg
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 5004    False
# 5005    False
# 5006    False
# 5007    False
# 5008     True
# Name: category, Length: 5009, dtype: bool

# %%
df[fcg]
# Out:
#             order_id  order_date       customer_name           city
# 1     CA-2018-100090  2018-07-08          Ed Braxton  San Francisco  \
# 6     CA-2018-100678  2018-04-18        Kunst Miller        Houston
# 7     CA-2018-100706  2018-12-16     Laurel Elliston    Springfield
# 13    CA-2018-100916  2018-10-21        Frank Hawley   Newport News
# 21    CA-2018-101462  2018-04-20  Benjamin Patterson    Los Angeles
# ...              ...         ...                 ...            ...
# 4997  US-2021-167318  2021-07-26     George Zrebassa    Los Angeles
# 4998  US-2021-167402  2021-01-13      Cathy Prescott    Springfield
# 4999  US-2021-167570  2021-12-08         Emily Grady   Philadelphia
# 5002  US-2021-168613  2021-10-08         Gary McGarr  New York City
# 5008  US-2021-169551  2021-07-07           Rob Lucas   Philadelphia
#
#        category       product_id    sales    profit
# 1     Furniture  FUR-TA-10003715  502.488  -87.9354
# ...

# %%
fck = (df['category']=='Furniture') & (df['sales'] >= 500)

# %%
df_furn = df[fck].sort_index()

# %%
df_furn
# Out:
#             order_id  order_date     customer_name           city   category
# 1     CA-2018-100090  2018-07-08        Ed Braxton  San Francisco  Furniture  \
# 13    CA-2018-100916  2018-10-21      Frank Hawley   Newport News  Furniture
# 24    CA-2018-101602  2018-12-15     Mick Crebagga        El Paso  Furniture
# 27    CA-2018-101931  2018-10-28      Todd Sumrall    Los Angeles  Furniture
# 79    CA-2018-105648  2018-03-03        Eva Jacobs      San Diego  Furniture
# ...              ...         ...               ...            ...        ...
# 4880  US-2021-134481  2021-08-27  Allen Rosenblatt       Franklin  Furniture
# 4955  US-2021-155425  2021-11-10         Ann Blume         Tucson  Furniture
# 4973  US-2021-160836  2021-09-11     Cindy Chapman        Houston  Furniture
# 4985  US-2021-164056  2021-04-29     Filia McAdams         Dublin  Furniture
# 4989  US-2021-165456  2021-11-30       Trudy Brown   Philadelphia  Furniture
#
#            product_id     sales    profit
# ...

# %%
df_furn.to_csv('orders_furn.csv')

# %%
df_furn
# Out:
#             order_id  order_date     customer_name           city   category
# 1     CA-2018-100090  2018-07-08        Ed Braxton  San Francisco  Furniture  \
# 13    CA-2018-100916  2018-10-21      Frank Hawley   Newport News  Furniture
# 24    CA-2018-101602  2018-12-15     Mick Crebagga        El Paso  Furniture
# 27    CA-2018-101931  2018-10-28      Todd Sumrall    Los Angeles  Furniture
# 79    CA-2018-105648  2018-03-03        Eva Jacobs      San Diego  Furniture
# ...              ...         ...               ...            ...        ...
# 4880  US-2021-134481  2021-08-27  Allen Rosenblatt       Franklin  Furniture
# 4955  US-2021-155425  2021-11-10         Ann Blume         Tucson  Furniture
# 4973  US-2021-160836  2021-09-11     Cindy Chapman        Houston  Furniture
# 4985  US-2021-164056  2021-04-29     Filia McAdams         Dublin  Furniture
# 4989  US-2021-165456  2021-11-30       Trudy Brown   Philadelphia  Furniture
#
#            product_id     sales    profit
# ...

# %%
df
# Out:
#             order_id  order_date      customer_name           city
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City  \
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
fmcondtn = (df['category']=='Furniture')  |  (df['sales'] >= 500)

# %%
fmcondtn
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 5004    False
# 5005    False
# 5006    False
# 5007    False
# 5008     True
# Length: 5009, dtype: bool

# %%
df[fmcondtn]
# Out:
#             order_id  order_date       customer_name           city
# 1     CA-2018-100090  2018-07-08          Ed Braxton  San Francisco  \
# 6     CA-2018-100678  2018-04-18        Kunst Miller        Houston
# 7     CA-2018-100706  2018-12-16     Laurel Elliston    Springfield
# 13    CA-2018-100916  2018-10-21        Frank Hawley   Newport News
# 21    CA-2018-101462  2018-04-20  Benjamin Patterson    Los Angeles
# ...              ...         ...                 ...            ...
# 4997  US-2021-167318  2021-07-26     George Zrebassa    Los Angeles
# 4998  US-2021-167402  2021-01-13      Cathy Prescott    Springfield
# 4999  US-2021-167570  2021-12-08         Emily Grady   Philadelphia
# 5002  US-2021-168613  2021-10-08         Gary McGarr  New York City
# 5008  US-2021-169551  2021-07-07           Rob Lucas   Philadelphia
#
#        category       product_id    sales    profit
# 1     Furniture  FUR-TA-10003715  502.488  -87.9354
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#             order_id  order_date           customer_name               city
# 0     CA-2018-100006  2018-09-07             Dennis Kane      New York City  \
# 1     CA-2018-100090  2018-07-08              Ed Braxton      San Francisco
# 2     CA-2018-100293  2018-03-14        Neil Französisch       Jacksonville
# 3     CA-2018-100328  2018-01-28         Jasper Cacioppo      New York City
# 4     CA-2018-100363  2018-04-08             Jim Mitchum           Glendale
# 5     CA-2018-100391  2018-05-25           Barry Weirich      New York City
# 6     CA-2018-100678  2018-04-18            Kunst Miller            Houston
# 7     CA-2018-100706  2018-12-16         Laurel Elliston        Springfield
# 8     CA-2018-100762  2018-11-24              Nat Gilpin            Jackson
# 9     CA-2018-100860  2018-03-26           Cindy Stewart             Pomona
# 10    CA-2018-100867  2018-10-19       Eugene Hildebrand           Lakewood
# ...
