# %%
import pandas as pd

# %%
###Read the iphone.csv dataset to pandas dataframe
df_iphone = pd.read_csv('/Users/B0264653/Desktop/Namaste-Python/project_2/iphone.csv')
df_iphone
# Out:
#                                 Product Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df_iphone.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Number Of Ratings', 'Number Of Reviews', 'Upc', 'Star Rating', 'Ram'],
#       dtype='object')

# %%
# 1 - The column names have spaces . rename the column names 
# to have underscore '_' instead of space (try to do in one go instead 
# of specifying each column nam in rename method)

df_iphone.rename (columns={'Product Name':'Product_Name', 'Product URL':'Product_URL','Sale Price': 'Sale_Price','Number Of Ratings': 'Number_Of_Reviews', 'Star Rating':'Star_Rating'},inplace=True)
df_iphone
# Out:
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# 2- start rating for some of the models is missing in
#  the dataset. fill those missing values with the average
#   rating all the models.

df_star_rating_mean = df_iphone['Star_Rating'].mean()
print(df_star_rating_mean)
df_iphone_d= df_iphone['Star_Rating'].fillna(value=df_star_rating_mean,inplace=True)
df_iphone
# Out:
# 4.576271186440679
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# 3- Now instead of filling missing values with avg rating of full dataset ,
# fill with avg rating based on RAM. example :  if rating for a 2 gb phone
# is missing then take average of all other 2 gb phones rating and 
# fill that value. 

df_star_rating_mean_grp = df_iphone.groupby('Ram')['Star_Rating'].mean()
print(df_star_rating_mean_grp)
df_iphone_grp= df_iphone['Star_Rating'].fillna(value=df_star_rating_mean,inplace=True)
df_iphone
# Out:
# Ram
# 2 GB    4.544329
# 3 GB    4.600000
# 4 GB    4.588837
# 6 GB    4.577698
# Name: Star_Rating, dtype: float64
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# ...

# %%
# 4- create a new column in the dataframe "Discount_Percentage" 
# based on MRP and sale value
df_iphone['Discount_Percentage'] = (df_iphone['Sale_Price']/df_iphone['Mrp'])*100
df_iphone
# Out:
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# 5- which model has highest percent discount ?
df_iphone_max= df_iphone.groupby('Product_Name')['Discount_Percentage'].max()
df_iphone_max
# Out:
# Product_Name
# APPLE iPhone 11 (Black, 128 GB)    91.818030
# APPLE iPhone 11 (Black, 64 GB)     85.608379
# APPLE iPhone 11 (Purple, 64 GB)    85.608379
# APPLE iPhone 11 (Red, 128 GB)      91.818030
# APPLE iPhone 11 (Red, 64 GB)       85.608379
#                                      ...
# Apple iPhone XR (Black, 128 GB)    79.393195
# Apple iPhone XR (Black, 64 GB)     83.505219
# Apple iPhone XR (Coral, 128 GB)    79.393195
# Apple iPhone XR (RED, 128 GB)      79.393195
# Apple iPhone XR (White, 128 GB)    79.393195
# Name: Discount_Percentage, Length: 62, dtype: float64

# %%
# 6- find total no of models  each space configuration (128 GB , 64 GB etc)
df_iphone_max= df_iphone.groupby('Ram')['Product_Name'].count()
df_iphone_max
# Out:
# Ram
# 2 GB    13
# 3 GB     1
# 4 GB    29
# 6 GB    19
# Name: Product_Name, dtype: int64

# %%
df_iphone
# Out:
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# 7- find total number of models for each color 
df_iphone[["model","color1"]] = df_iphone['Product_Name'].str.split("(", expand = True)
df_iphone.groupby('model')['model'].count()
# Out:
# model
# APPLE iPhone 11             7
# APPLE iPhone 11 Pro         4
# APPLE iPhone 11 Pro Max     5
# APPLE iPhone 12             7
# APPLE iPhone 12 Mini        6
# APPLE iPhone 12 Pro         5
# APPLE iPhone 12 Pro Max     8
# APPLE iPhone 8              3
# APPLE iPhone 8 Plus         5
# APPLE iPhone SE             5
# APPLE iPhone XS Max         1
# Apple iPhone SE             1
# Apple iPhone XR             5
# Name: model, dtype: int64

# %%
df_iphone[["color","specify"]] = df_iphone['color1'].str.split(",", expand = True)
df_iphone.drop(['color1','specify'],axis=1,inplace=True)

# %%
df_iphone['version'] = df_iphone['model'].str[6:15]
df_iphone
# Out:
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# 8- find total number of models by iphone version 

df_iphone.groupby('version')['model'].count()
# Out:
# version
# iPhone 11    16
# iPhone 12    26
# iPhone 8      8
# iPhone SE     6
# iPhone XR     5
# iPhone XS     1
# Name: model, dtype: int64

# %%
# 9- list top 5 models having highest no of reviews 

df_iphone.groupby('model')['Number_Of_Reviews'].sum().sort_values(ascending=False).head(5)
# Out:
# model
# APPLE iPhone SE     479341
# Apple iPhone XR     397630
# APPLE iPhone 11     304764
# Apple iPhone SE      95909
# APPLE iPhone 8       33606
# Name: Number_Of_Reviews, dtype: int64

# %%
# 10 - what is the price diffrence between highest price and
# lowest price iphone (based on mrp)

df_iphone_max = df_iphone['Mrp'].max()
df_iphone_min = df_iphone['Mrp'].min()
df_iphone_diff = df_iphone_max -  df_iphone_min
df_iphone_diff
# Out:
# 110000

# %%
df_iphone
# Out:
#                                 Product_Name
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df_iphone['version']=='iPhone 11'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58     True
# 59     True
# 60     True
# 61     True
# Name: version, Length: 62, dtype: bool

# %%
# 11 - find total no of reviews for iphone 11 and iphone 12 category . 
# Output should have only 2 rows (for 11 and 12).

df1 = df_iphone.query('version  == "iPhone 12" | version  == "iPhone 11"').groupby('version')['Number_Of_Reviews'].sum()
df1
# Out:
# version
# iPhone 11    338499
# iPhone 12     26471
# Name: Number_Of_Reviews, dtype: int64

# %%
# 12- which iphone has 3rd highest MRP

df2 = df_iphone.sort_values("Mrp",ascending=False).nlargest(3,['Mrp'])
df2.sort_values("Mrp",ascending=False).head(1)
# Out:
#                                   Product_Name
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)  \
#
#                                           Product_URL  Brand  Sale_Price
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900  \
#
#        Mrp  Number_Of_Reviews  Number Of Reviews               Upc
# 41  149900                545                 42  MOBFWBYZTHSXKMGW  \
#
#     Star_Rating   Ram  Discount_Percentage                 model
# 41          4.5  4 GB            93.995997  APPLE iPhone 12 Pro   \
#
#            color    version
# 41  Pacific Blue  iPhone 12

# %%
df_iphone.dtypes
# Out:
# Product_Name            object
# Product_URL             object
# Brand                   object
# Sale_Price               int64
# Mrp                      int64
# Number_Of_Reviews        int64
# Number Of Reviews        int64
# Upc                     object
# Star_Rating            float64
# Ram                     object
# Discount_Percentage    float64
# model                   object
# color                   object
# version                 object
# dtype: object

# %%
# 13- what is the average mrp of iphones which costs above 100,000
df_iphone_avg = df_iphone.query('Mrp>100000')
df_iphone_avg['Mrp'].mean()
# Out:
# 130559.09090909091

# %%
# 14- which iphone with 128 GB space has highest ratings to review ratio
df_iphone_space = df_iphone.query('Ram == "128 GB"').sort_values("Star_Rating",ascending=False).head(1)
df_iphone_space
# Out:
# Empty DataFrame
# Columns: [Product_Name, Product_URL, Brand, Sale_Price, Mrp, Number_Of_Reviews, Number Of Reviews, Upc, Star_Rating, Ram, Discount_Percentage, model, color, version]
# Index: []
